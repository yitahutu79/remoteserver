# %%
import json
data_doc8 = json.load(open('/data/lj/llm/dataset/test&train/train_data.json','r',encoding='utf8'))
data_doc3 = json.load(open('/data/lj/llm/dataset/test&train/train_3000.json','r',encoding='utf8'))

# %%
test_data = json.load(open('/data/lj/llm/dataset/test&train/test_100.json','r',encoding='utf8'))
print(test_data[0])
docs = []
for test_dat in test_data:
    docs.append(test_dat['input'])
# Out:
# {'instruction': '你是一名电商人工客服,现在不是工作时间不要求你用客服语气说话,只是考验你从文档中抽取信息的能力,请你通过分析文档内容后精简的回答问题。\n 以下是供你参考的已知信息：到了19世纪70年代中期，大多数科学家接受了进化论，但由于他们认为进化是有目的的和进步的，自然选择被放在次要地位。“达尔文主义的日食”时期的进化论包括“跳跃论”的形式，其中新物种被认为是通过“跳跃”而不是逐渐适应而产生的，正生学的形式声称物种有一种内在的倾向在特定的方向上变化，新拉马克主义的形式，继承后天的特征导致进步。奥古斯特·魏斯曼（August Weismann）认为自然选择是唯一机制的少数观点被称为新达尔文主义。人们认为孟德尔遗传的重新发现使达尔文的观点失效。\n\n你要回复的问题是:', 'output': '他们认为进化是有目的的和进步的', 'input': '为什么大多数科学家在19世纪70年代就接受了进化论的有效性，却认为自然选择只是进化论的一小部分？', 'history': []}

# %%
idx = 0
for dat in data_doc3:
    if dat['input'] in docs:
        print(dat['instruction'])
        print(dat['input'])
        print(dat['output'])
        print("*" * 50)
        idx +=1
print(idx)
# Out:
# 你是一名电商人工客服,现在不是工作时间不要求你用客服语气说话,只是考验你从文档中抽取信息的能力,请你通过分析文档内容后精简的回答问题。
#  以下是供你参考的已知信息：本院经审理认定事实如下:2015年4月29日19时15分许,刘x16驾驶闽J&times;&times;&times;&times;&times;号小型轿车(承载苏昱洁)从福安市溪潭镇镇区沿省道302线往康厝乡镇区方向行驶,行经省道302线40KM+790M路段,在交会车时为避让前方路面沙堆将车驶入路左,碰撞相向前方由陆x6驾驶为被告随州创捷公司所有的鄂S&times;&times;&times;&times;&times;号重型平板货车,造成两车不同程度损坏,刘x16、苏昱洁受伤的交通事故经福安市公安局交通管理大队认定,刘x16负事故主要责任,陆x6负事故次要责任,施工作业单位宁德路桥公司负事故次要责任刘x16驾驶闽J&times;&times;&times;&times;&times;号小型轿车的车辆损失险投保于原告处,保险金额114120元,保险期限自2014年5月9日0时至2015年5月8日24时陆x6驾驶的鄂S&times;&times;&times;&times;&times;号重型平板货车为被告随州创捷公司所有,交强险、商业险均投保于被告平安财保随州支公司,保险期限自2014年5月24日0时至2015年5月23日24时,商业险第三者保险限额为50万元,不计免赔2016年3月11日,刘x16向原告主张事故车辆闽J&times;&times;&times;&times;&times;号小型轿车车辆损失的索赔申请,刘x16与原告就车辆损失达成定损协议,同意在扣除残值后的车损为67200元刘x16事故车辆共支出施救费1500元,双方同意按1300元确定施救费2016年3月11日,刘x16向原告所属的人保财险福建分公司出具机动车保险权益转让书,因其名下的闽J&times;&times;&times;&times;&times;号车辆于2015年4月29日发生事故,将已取得赔款部分保险标的一切权益转让给原告所属的人保财险福建分公司原告所属的人保财险福建分公司于2016年3月15日向刘x16支付理赔款68500元人保财险福建分公司已授权其下属公司原告予以追偿
#
# 你要回复的问题是:
# ...

# %%
idx = 0
for dat in data_doc8:
    if dat['input'] in docs:
        idx +=1
        print(dat['instruction'])
        print(dat['input'])
        print(dat['output'])
        print("*" * 50)
print(idx)
# Out:
# 你是一名电商人工客服,现在不是工作时间不要求你用客服语气说话,只是考验你从文档中抽取信息的能力,请你通过分析文档内容后精简的回答问题。
#  以下是供你参考的已知信息：本院经审理认定事实如下:2015年4月29日19时15分许,刘x16驾驶闽J&times;&times;&times;&times;&times;号小型轿车(承载苏昱洁)从福安市溪潭镇镇区沿省道302线往康厝乡镇区方向行驶,行经省道302线40KM+790M路段,在交会车时为避让前方路面沙堆将车驶入路左,碰撞相向前方由陆x6驾驶为被告随州创捷公司所有的鄂S&times;&times;&times;&times;&times;号重型平板货车,造成两车不同程度损坏,刘x16、苏昱洁受伤的交通事故经福安市公安局交通管理大队认定,刘x16负事故主要责任,陆x6负事故次要责任,施工作业单位宁德路桥公司负事故次要责任刘x16驾驶闽J&times;&times;&times;&times;&times;号小型轿车的车辆损失险投保于原告处,保险金额114120元,保险期限自2014年5月9日0时至2015年5月8日24时陆x6驾驶的鄂S&times;&times;&times;&times;&times;号重型平板货车为被告随州创捷公司所有,交强险、商业险均投保于被告平安财保随州支公司,保险期限自2014年5月24日0时至2015年5月23日24时,商业险第三者保险限额为50万元,不计免赔2016年3月11日,刘x16向原告主张事故车辆闽J&times;&times;&times;&times;&times;号小型轿车车辆损失的索赔申请,刘x16与原告就车辆损失达成定损协议,同意在扣除残值后的车损为67200元刘x16事故车辆共支出施救费1500元,双方同意按1300元确定施救费2016年3月11日,刘x16向原告所属的人保财险福建分公司出具机动车保险权益转让书,因其名下的闽J&times;&times;&times;&times;&times;号车辆于2015年4月29日发生事故,将已取得赔款部分保险标的一切权益转让给原告所属的人保财险福建分公司原告所属的人保财险福建分公司于2016年3月15日向刘x16支付理赔款68500元人保财险福建分公司已授权其下属公司原告予以追偿
#
# 你要回复的问题是:
# ...
